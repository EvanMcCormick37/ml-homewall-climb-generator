# %%
from preprocess_climb_data import load_and_preprocess_climbs, augment_dataset

# %%
sequences, climbs, grades = load_and_preprocess_climbs("data/spraywall-climbs.json")
sequences, climbs, grades = augment_dataset(sequences, climbs, grades)
# Out:
# Profit Motive
# Extraction Point
# Scorpion Play
# Big Moves Fim
# Dynamic Introduction
# Couch Set 1
# Heeliez
# Pogo Stick Cop
# From Russia With Love
# From Russia With Love, OG Beta
# Gestalt Autobiography
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 sequences, climbs, grades = load_and_preprocess_climbs("data/spraywall-climbs.json")
# ----> 2 sequences, climbs, grades = augment_dataset(sequences, climbs, grades)
#
# File ~\Documents\Projects\GitHub\ml-homewall-climb-generator\feature-embedding\preprocess_climb_data.py:188, in augment_dataset(sequences, names, grades)
#     186 print(name)
#     187 mirrored = mirror_climb(seq)
# --> 188 trans_left, trans_right = translate_climb(seq)
#     189 aug_sequences.extend([mirrored, trans_left, trans_right])
#     190 aug_names.extend([f"{name} (mirrored)",f"{name} (left)",f"{name} (right)"])
#
# ...

# %%
climbs
# Out:
# ['Profit Motive',
#  'Extraction Point',
#  'Scorpion Play',
#  'Big Moves Fim',
#  'Dynamic Introduction',
#  'Couch Set 1',
#  'Heeliez',
#  'Pogo Stick Cop',
#  'From Russia With Love',
#  'From Russia With Love, OG Beta',
#  'Gestalt Autobiography',
#  'Wubbalubbadubdub Jump',
#  "Black Tar Bumpin'",
#  'Basketball',
#  'Gbyaaaah! ...Hueeeegh!',
#  'The Green Meanie',
#  'Pogo Light',
#  'Shane Gillis Files',
#  'Fedex Gestalt Consciousness',
#  'Thin Flake Crimps',
#  "Bones Don't Rust",
#  'Flex Squeal',
#  'Return of the Moranth',
#  'History of Violence',
#  'Damp Barrel of Dynamite',
#  'CHIPS Act',
#  'Whipping Wind, Streaming Hair',
#  'Traversussy',
#  'Sidepulls Pockets Crimps',
#  'Open Feet #1',
#  'Profit Motive (mirrored)',
#  'Extraction Point (mirrored)',
#  'Scorpion Play (mirrored)',
#  'Big Moves Fim (mirrored)',
#  'Dynamic Introduction (mirrored)',
#  'Couch Set 1 (mirrored)',
#  'Heeliez (mirrored)',
#  'Pogo Stick Cop (mirrored)',
# ...
