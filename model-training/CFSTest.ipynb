# %%
from climb_conversion import ClimbsFeatureArrayV3
cfa = ClimbsFeatureArrayV3()
climbs = cfa.get_features()
# Out:
# Initializing ClimbsFeatureArray...
# ClimbsFeatureArray initialized! 92651 unique climbs added!
# Hold feature vector: 11-dim ['x', 'y', 'pull_x', 'pull_y', 'useability', 'is_foot', 'sloper', 'pinch', 'macro', 'flat', 'jug']

# %%
len(climbs)
# Out:
# 185298

# %%
import sqlite3


for i in range(10):
    with sqlite3.connect('data/storage.db') as conn:
        print(conn.execute('SELECT COUNT(*) FROM climbs WHERE ascents > ?',(i,)).fetchone())
# Out:
# (301243,)
# (161972,)
# (95355,)
# (63298,)
# (46755,)
# (36172,)
# (29324,)
# (24357,)
# (20901,)
# (18108,)
