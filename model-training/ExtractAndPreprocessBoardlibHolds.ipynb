# %%
import json
import requests
from pathlib import Path
import pandas as pd
import numpy as np
import seaborn as sns
import sqlite3
from sklearn.preprocessing import MinMaxScaler
from boardlib_preprocessing import df_sql, parse_frames_to_holdset, convert_dataframe_to_holds, add_useability_features, upload_holds, flush_backup_holds, upload_climbs_batch, delete_wall
from db_migration import migrate_boardlib_climbs, SOURCE_DBS_WITH_LAYOUTS
from add_hold_useability import add_hold_useability, _build_hold_difficulty_df, API_BASE_URL

# %%
df_holes = df_sql("tension","SELECT id, hole_id, layout_id FROM placements", index_col=None)
df_holes_dict = {}
for layout in list(set(df_holes['layout_id'])):
    in_layout = (df_holes["layout_id"]==layout)
    df_holes_dict[layout] = dict(zip(df_holes.loc[in_layout,"hole_id"],df_holes.loc[in_layout,"id"]))

wall_ids = ["wall-0a877f13d8e5", "wall-443c15cd12e0"]
layouts = [10,11]
for wall_id, layout in zip(wall_ids, layouts):
    endpoint = f"{API_BASE_URL}/api/v1/walls/{wall_id}"
    response = requests.get(endpoint)
    response.raise_for_status()

    holds = response.json()['holds']

    for hold in holds:
        idx = hold["hold_index"]
        hold["hold_index"] = df_holes_dict[layout][idx]
# Out:
#   Cell In[26], line 9
#     for wall_id, source_id in zip(wall_ids, source_ids):
#                                                         ^
# SyntaxError: incomplete input

# %%
wall_ids = ["wall-0a877f13d8e5", "wall-443c15cd12e0", "wall-e77a688049fb", "wall-9e000814e880", "wall-0db605e544b3"]
source_ids = ["tension-10","tension-11","kilter-1","decoy-2","grasshopper-1"]
for wall_id, source_id in zip(wall_ids, source_ids):
    add_hold_useability(wall_id, source_id, min_ascents=2)
# Out:
# Loading climbs for wall 'tension-10' from data\storage.db ...
#   25441 climbs loaded.
# Computing hold useability scores ...
#   Scores computed for 498 unique holds.
# Fetching holds for API wall 'wall-0a877f13d8e5' ...
#   498 holds fetched.
#   362/498 holds updated with new useability scores.
# Uploading updated holds to API wall 'wall-0a877f13d8e5' ...
# Uploading 498 holds to wall wall-0a877f13d8e5...
# Endpoint: http://localhost:8000/api/v1/walls/wall-0a877f13d8e5/holds
# ✓ Successfully uploaded 498 holds!
# Done.
# Loading climbs for wall 'tension-11' from data\storage.db ...
#   16454 climbs loaded.
# Computing hold useability scores ...
#   Scores computed for 498 unique holds.
# Fetching holds for API wall 'wall-443c15cd12e0' ...
#   498 holds fetched.
#   139/498 holds updated with new useability scores.
# Uploading updated holds to API wall 'wall-443c15cd12e0' ...
# Uploading 498 holds to wall wall-443c15cd12e0...
# Endpoint: http://localhost:8000/api/v1/walls/wall-443c15cd12e0/holds
# ✓ Successfully uploaded 498 holds!
# Done.
# Loading climbs for wall 'kilter-1' from data\storage.db ...
#   167219 climbs loaded.
# Computing hold useability scores ...
#   Scores computed for 689 unique holds.
# Fetching holds for API wall 'wall-e77a688049fb' ...
#   641 holds fetched.
#   424/641 holds updated with new useability scores.
# Uploading updated holds to API wall 'wall-e77a688049fb' ...
# Uploading 641 holds to wall wall-e77a688049fb...
# Endpoint: http://localhost:8000/api/v1/walls/wall-e77a688049fb/holds
# ✓ Successfully uploaded 641 holds!
# Done.
# Loading climbs for wall 'decoy-2' from data\storage.db ...
#   6205 climbs loaded.
# Computing hold useability scores ...
#   Scores computed for 458 unique holds.
# Fetching holds for API wall 'wall-9e000814e880' ...
#   458 holds fetched.
#   458/458 holds updated with new useability scores.
# Uploading updated holds to API wall 'wall-9e000814e880' ...
# Uploading 458 holds to wall wall-9e000814e880...
# Endpoint: http://localhost:8000/api/v1/walls/wall-9e000814e880/holds
# ✓ Successfully uploaded 458 holds!
# Done.
# Loading climbs for wall 'grasshopper-1' from data\storage.db ...
#   15358 climbs loaded.
# Computing hold useability scores ...
#   Scores computed for 466 unique holds.
# Fetching holds for API wall 'wall-0db605e544b3' ...
#   466 holds fetched.
#   466/466 holds updated with new useability scores.
# Uploading updated holds to API wall 'wall-0db605e544b3' ...
# Uploading 466 holds to wall wall-0db605e544b3...
# Endpoint: http://localhost:8000/api/v1/walls/wall-0db605e544b3/holds
# ✓ Successfully uploaded 466 holds!
# Done.

# %%
dfg = df_sql('grasshopper', "SELECT * FROM holes", index_col='id')
dfg['x_ft'] = dfg['x']/12 + 6
dfg['y_ft'] = dfg['y']/12
dfg.sort_values('y').head()

# %%
dfp = df_sql("grasshopper", "SELECT * FROM placements", "id")
dfp = pd.merge(dfp, dfg, left_on="hole_id", right_index=True, how="inner")[['default_placement_role_id', "x_ft", "y_ft"]]
dfp['is_foot'] = (dfp['default_placement_role_id']==4)
dfp

# %%
holds = convert_dataframe_to_holds(dfp)
upload_holds('wall-0db605e544b3',holds)
# delete_wall('wall-e8ced52d826f')

# %%
query="""
        SELECT 
            c.uuid,
            c.name,
            cs.angle,
            c.frames,
            cs.difficulty_average,
            cs.quality_average,
            cs.fa_username,
            c.created_at
        FROM climbs c
        JOIN climb_stats cs ON c.uuid = cs.climb_uuid
        WHERE cs.difficulty_average IS NOT NULL
            AND cs.quality_average IS NOT NULL
        ORDER BY cs.ascensionist_count DESC;
    """
df_climbs = df_sql("grasshopper",query)
df_climbs['ascensionist_count'] = 1

upload_climbs_batch(
    'wall-87059ecf9a99',
    df_climbs,
)

# %%
df_climbs = df_sql("grasshopper","SELECT * FROM climbs")
from sklearn.preprocessing import MinMaxScaler
grades_dict = {}
for i, row in df_climbs.iterrows():
    try:
        holdset = parse_frames_to_holdset(row['frames'])
        for h in [h for l in holdset.values() for h in l]:
            if h not in grades_dict:
                grades_dict[h] = []
            grades_dict[h].append(row['difficulty_average'])
    except:
        continue
scaler = MinMaxScaler(feature_range=(1,100))
df_hold_diff = pd.DataFrame(np.array([[k,1/np.mean(v)] for k, v in grades_dict.items()]), columns=['hold_index','difficulty_level']).set_index('hold_index')
df_hold_diff['difficulty_level'] = np.round(scaler.fit_transform(df_hold_diff[['difficulty_level']])/100,2)
df_hold_diff.sort_values('difficulty_level')

# %%
query='SELECT * FROM holes'
df_holes = df_sql("decoy", query, index_col='id').astype({'product_id':int, 'name':str,'x':int,'y':int,'mirrored_hole_id':int,'mirror_group':int})
df_holes.head()

# %%
sns.scatterplot(df_holes, x='x',y='y')

# %% [markdown]
# ### Product 4 is the TB1, Product 5 is the TB2. We need to convert both of these hold-sets to real, physical holds. First step would be aligning them with their real, physical location on the board. Second step would be finding some way to manually add pull_dir+useability features.
#
# I learned from the TB2 installation guide that these hole location measurements are in inches. Additionally, the TB2 DOESN'T HAVE A KICKBOARD! That's crazy, and a bit of a Mandela effect for me. I could swear it had one. But nope.
#
# **The guide also comes with crystal clear hold orientations, and difficulty levels. This is exactly the data I'm looking for! Fuck yeah, Tension!**

# %%
query = "SELECT * FROM placements WHERE layout_id = 2"
df_placements = df_sql("decoy",query,index_col=None).astype({'id':int,'layout_id':int,'hole_id':int,'set_id':int,'default_placement_role_id':int})
df_placements = pd.merge(
    df_placements,
    df_holes,
    left_on='hole_id',
    right_on=df_holes.index,
    how='inner'
)
min_x = df_placements['x'].min()
df_placements.loc[df_placements['id'].isin([950, 935]), 'y'] += 8
df_placements['x_ft'] = (df_placements['x']+8.5-min_x)/12
df_placements['y_ft'] = (df_placements['y']+8)/12
df_placements['is_foot'] = (df_placements['default_placement_role_id']%4==0).astype(int)
df_placements = df_placements[['id','hole_id','x_ft','y_ft','is_foot']].sort_values('id')
print(
    df_placements['x_ft'].max(),
    df_placements['y_ft'].max()
)
df_placements.head()

# %%
decoy_holds = convert_dataframe_to_holds(df_placements)
upload_holds('wall-9e000814e880',decoy_holds)

# %%
flush_backup_holds("wall-e77a688049fb")

# %%
from sklearn.preprocessing import MinMaxScaler
grades_dict = {}
for i, row in df_climbs.iterrows():
    try:
        holdset = parse_frames_to_holdset(row['frames'])
        for h in [h for l in holdset.values() for h in l]:
            if h not in grades_dict:
                grades_dict[h] = []
            grades_dict[h].append(row['difficulty_average'])
    except:
        continue
scaler = MinMaxScaler(feature_range=(1,100))
df_hold_diff = pd.DataFrame(np.array([[k,1/np.mean(v)] for k, v in grades_dict.items()]), columns=['hold_index','difficulty_level']).set_index('hold_index')
df_hold_diff['difficulty_level'] = np.round(scaler.fit_transform(df_hold_diff[['difficulty_level']])/100,2)
df_hold_diff.sort_values('difficulty_level')
