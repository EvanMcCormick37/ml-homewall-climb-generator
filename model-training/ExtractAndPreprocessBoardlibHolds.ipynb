# %%
import json
import requests
from pathlib import Path
import pandas as pd
import numpy as np
import seaborn as sns
import sqlite3
from collections import defaultdict
from sklearn.preprocessing import MinMaxScaler
from db_migration import migrate_boardlib_climbs, _build_role_map, SOURCE_DBS_WITH_LAYOUTS
from add_hold_useability import add_hold_useability, _build_hold_difficulty_dict, diff_df, API_BASE_URL, STORAGE_DB

# %%
bz_ids = [
"layout-0aa86d03949f",
"layout-95a3f6e2ba1a",
"layout-f712a64fc0dc",
"layout-f6702371e300",
"layout-f311591b6b8b",
"layout-47aa8b2f3cbc",
"layout-5311e4b5fa08",
]
bl_dbs = ["kilter", "kilter", "tension", "grasshopper", "tension", "decoy", "tension"]
bl_ids = [1, 8, 10, 1, 11, 2, 9]
min_ascents = [8,3,3,2,3,2,5]
for bz_id, bl_db, bl_id, min_ascent in zip(bz_ids, bl_dbs, bl_ids, min_ascents):
    # add_holds(bl_db, bl_id, bz_id)
    add_hold_useability(bz_id, f"{bl_db}-{bl_id}", min_ascents=min_ascent)
    # diff_df(f"{bl_db}-{bl_id}", min_ascents=min_ascent)
# Out:
# Loading climbs for wall 'kilter-1' from data\storage.db ...
#   44908 climbs loaded.
# Computing hold useability scores ...
# Fetching holds for API layout 'layout-0aa86d03949f' ...
#   691 holds fetched.
#   653/691 holds updated with new useability scores.
# Uploading updated holds to API wall 'layout-0aa86d03949f' ...
# Uploading 691 holds to wall layout-0aa86d03949f...
# Endpoint: http://localhost:8000/api/v1/layouts/layout-0aa86d03949f/holds
# ✓ Successfully uploaded 691 holds!
# Done.
# Loading climbs for wall 'kilter-8' from data\storage.db ...
#   23489 climbs loaded.
# Computing hold useability scores ...
# Fetching holds for API layout 'layout-95a3f6e2ba1a' ...
#   499 holds fetched.
#   499/499 holds updated with new useability scores.
# Uploading updated holds to API wall 'layout-95a3f6e2ba1a' ...
# Uploading 499 holds to wall layout-95a3f6e2ba1a...
# Endpoint: http://localhost:8000/api/v1/layouts/layout-95a3f6e2ba1a/holds
# ✓ Successfully uploaded 499 holds!
# Done.
# ...

# %%
df = diff_df('kilter-1',8)
sns.histplot(df, x='useability')
sns.kdeplot(df, x='useability')
# Out:
# <Axes: xlabel='useability', ylabel='Count'>
