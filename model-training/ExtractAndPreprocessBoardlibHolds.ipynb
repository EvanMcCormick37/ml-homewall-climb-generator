# %%
import json
import requests
from pathlib import Path
import pandas as pd
import numpy as np
import seaborn as sns
import sqlite3
from sklearn.preprocessing import MinMaxScaler
from boardlib_preprocessing import df_sql, parse_frames_to_holdset, convert_dataframe_to_holds, add_useability_features, upload_holds, add_holds, flush_backup_holds, upload_climbs_batch, delete_wall
from db_migration import migrate_boardlib_climbs, _build_role_map, SOURCE_DBS_WITH_LAYOUTS
from add_hold_useability import add_hold_useability, _build_hold_difficulty_df, API_BASE_URL

# %%
bz_ids = [
"layout-0aa86d03949f",
"layout-95a3f6e2ba1a",
"layout-f712a64fc0dc",
"layout-f6702371e300",
"layout-f311591b6b8b",
"layout-47aa8b2f3cbc",
"layout-5311e4b5fa08"
]
bl_dbs = ["kilter", "kilter", "tension", "grasshopper", "tension", "decoy", "tension"]
bl_ids = [1, 7, 10, 1, 11, 2, 9]
min_ascents = [8,3,3,2,3,2,5]
for bz_id, bl_db, bl_id, min_ascent in zip(bz_ids, bl_dbs, bl_ids, min_ascents):
    add_holds(bl_db, bl_id, bz_id)
    add_hold_useability(bz_id, f"{bl_db}-{bl_id}", min_ascents=min_ascent)
# Out:
# Uploading 692 holds to wall layout-0aa86d03949f...
# Endpoint: http://localhost:8000/api/v1/layouts/layout-0aa86d03949f/holds
# ✓ Successfully uploaded 692 holds!
# Loading climbs for wall 'kilter-1' from data\storage.db ...
#   44908 climbs loaded.
# Computing hold useability scores ...
#   Scores computed for 585 unique holds.
# Fetching holds for API layout 'layout-0aa86d03949f' ...
#   692 holds fetched.
#   585/692 holds updated with new useability scores.
# Uploading updated holds to API wall 'layout-0aa86d03949f' ...
# Uploading 692 holds to wall layout-0aa86d03949f...
# Endpoint: http://localhost:8000/api/v1/layouts/layout-0aa86d03949f/holds
# ✓ Successfully uploaded 692 holds!
# Done.
# Uploading 479 holds to wall layout-95a3f6e2ba1a...
# Endpoint: http://localhost:8000/api/v1/layouts/layout-95a3f6e2ba1a/holds
# ✓ Successfully uploaded 479 holds!
# Loading climbs for wall 'kilter-7' from data\storage.db ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 7
#       5 for bz_id, bl_db, bl_id, min_ascent in zip(bz_ids, bl_dbs, bl_ids, min_ascents):
#       6     add_holds(bl_db, bl_id, bz_id)
# ----> 7     add_hold_useability(bz_id, f"{bl_db}-{bl_id}", min_ascents=min_ascent)
#
# File c:\Users\EvanM\Documents\Projects\GitHub\ml-homewall-climb-generator\model-training\add_hold_useability.py:146, in add_hold_useability(api_layout_id, training_wall_name, storage_db, api_base_url, min_ascents, verbose)
#     143     climbs = pd.read_sql_query(query, conn, params=params)
#     145 if climbs.empty:
# --> 146     raise ValueError(
#     147         f"No climbs found for wall_id='{training_wall_name}' in {storage_db}. "
#     148         "Run db_migration.migrate_boardlib_climbs() first."
#     149     )
#     151 if verbose:
#     152     print(f"  {len(climbs)} climbs loaded.")
#
# ValueError: No climbs found for wall_id='kilter-7' in data\storage.db. Run db_migration.migrate_boardlib_climbs() first.
