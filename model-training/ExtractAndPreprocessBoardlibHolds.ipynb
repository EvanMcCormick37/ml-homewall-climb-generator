# %%
import collections
import json
import requests
import sqlite3
import re
from pathlib import Path
from datetime import datetime
import numpy as np
import pandas as pd
from boardlib_preprocessing import add_default_hold_roles, upload_holds, STORAGE_DB, API_BASE_URL, add_hold_useability, move_holds_to_db

# %%
move_holds_to_db("layout-a611b479b219")
# Out:
# Fetching holds for API layout 'layout-0aa86d03949f' ...
#   691 holds fetched.
#   13119 climbs loaded.
# Computing hold useability scores ...
#   650/691 holds updated with new useability scores.
# Uploading updated holds to API wall 'layout-0aa86d03949f' ...
# Uploading 691 holds to wall layout-0aa86d03949f...
# Endpoint: http://localhost:8000/api/v1/layouts/layout-0aa86d03949f/holds
# ✓ Successfully uploaded 691 holds!
# Done.

# %%
bz_ids = [
"layout-0aa86d03949f",
"layout-95a3f6e2ba1a",
"layout-f712a64fc0dc",
"layout-f6702371e300",
"layout-f311591b6b8b",
"layout-47aa8b2f3cbc",
"layout-5311e4b5fa08",
]
bl_dbs = ["kilter", "kilter", "tension", "grasshopper", "tension", "decoy", "tension"]
bl_ids = [1, 8, 10, 1, 11, 2, 9]
min_ascents = [8,3,3,2,3,2,5]
for bz_id, bl_db, bl_id, min_ascent in zip(bz_ids, bl_dbs, bl_ids, min_ascents):
    # add_holds(bl_db, bl_id, bz_id)
    # add_hold_useability(bz_id, min_ascents=min_ascent, to_hand_ratio=0.1)
    move_holds_to_db(bz_id)
# Out:
# Successfully uploaded 691 holds to training DB!
# Successfully uploaded 499 holds to training DB!
# Successfully uploaded 498 holds to training DB!
# Successfully uploaded 466 holds to training DB!
# Successfully uploaded 498 holds to training DB!
# Successfully uploaded 458 holds to training DB!
# Successfully uploaded 303 holds to training DB!
