# %%
import json
import requests
import pandas as pd
import numpy as np
import seaborn as sns
from boardlib_preprocessing import df_sql, parse_frames_to_holdset, convert_dataframe_to_holds, add_useability_features, upload_holds, flush_backup_holds, upload_climbs_batch, delete_wall
from db_migration import migrate_boardlib_climbs, SOURCE_DBS_WITH_LAYOUTS
from add_hold_useability import add_hold_useability

# %%
migrate_boardlib_climbs()
# Out:
# [kilter] Opening data\boardlib\kilter.db ...
# [kilter] Role map: {12: 0, 13: 2, 14: 1, 15: 3, 20: 0, 21: 2, 22: 1, 23: 3, 24: 0, 25: 2, 26: 1, 27: 3, 28: 0, 29: 2, 30: 1, 31: 3, 32: 0, 33: 2, 34: 1, 35: 3, 42: 0, 43: 2, 44: 1, 45: 3}
# [kilter, layout id 1] 287641 candidate (climb, angle) pairs.
# [kilter]   1000 inserted so far ...
# [kilter]   2000 inserted so far ...
# [kilter]   3000 inserted so far ...
# [kilter]   4000 inserted so far ...
# [kilter]   5000 inserted so far ...
# [kilter]   6000 inserted so far ...
# [kilter]   7000 inserted so far ...
# [kilter]   8000 inserted so far ...
# [kilter]   9000 inserted so far ...
# [kilter]   10000 inserted so far ...
# [kilter]   11000 inserted so far ...
# [kilter]   12000 inserted so far ...
# [kilter]   13000 inserted so far ...
# [kilter]   14000 inserted so far ...
# [kilter]   15000 inserted so far ...
# [kilter]   16000 inserted so far ...
# [kilter]   17000 inserted so far ...
# [kilter]   18000 inserted so far ...
# [kilter]   19000 inserted so far ...
# [kilter]   20000 inserted so far ...
# [kilter]   21000 inserted so far ...
# [kilter]   22000 inserted so far ...
# [kilter]   23000 inserted so far ...
# [kilter]   24000 inserted so far ...
# [kilter]   25000 inserted so far ...
# [kilter]   26000 inserted so far ...
# [kilter]   27000 inserted so far ...
# [kilter]   28000 inserted so far ...
# [kilter]   29000 inserted so far ...
# [kilter]   30000 inserted so far ...
# [kilter]   31000 inserted so far ...
# [kilter]   32000 inserted so far ...
# [kilter]   33000 inserted so far ...
# [kilter]   34000 inserted so far ...
# [kilter]   35000 inserted so far ...
# [kilter]   36000 inserted so far ...
# [kilter]   37000 inserted so far ...
# [kilter]   38000 inserted so far ...
# [kilter]   39000 inserted so far ...
# [kilter]   40000 inserted so far ...
# [kilter]   41000 inserted so far ...
# [kilter]   42000 inserted so far ...
# [kilter]   43000 inserted so far ...
# [kilter]   44000 inserted so far ...
# [kilter]   45000 inserted so far ...
# [kilter]   46000 inserted so far ...
# [kilter]   47000 inserted so far ...
# [kilter]   48000 inserted so far ...
# [kilter]   49000 inserted so far ...
# [kilter]   50000 inserted so far ...
# [kilter]   51000 inserted so far ...
# [kilter]   52000 inserted so far ...
# [kilter]   53000 inserted so far ...
# [kilter]   54000 inserted so far ...
# [kilter]   55000 inserted so far ...
# [kilter]   56000 inserted so far ...
# [kilter]   57000 inserted so far ...
# [kilter]   58000 inserted so far ...
# [kilter]   59000 inserted so far ...
# [kilter]   60000 inserted so far ...
# [kilter]   61000 inserted so far ...
# [kilter]   62000 inserted so far ...
# [kilter]   63000 inserted so far ...
# [kilter]   64000 inserted so far ...
# [kilter]   65000 inserted so far ...
# [kilter]   66000 inserted so far ...
# [kilter]   67000 inserted so far ...
# [kilter]   68000 inserted so far ...
# [kilter]   69000 inserted so far ...
# [kilter]   70000 inserted so far ...
# [kilter]   71000 inserted so far ...
# [kilter]   72000 inserted so far ...
# [kilter]   73000 inserted so far ...
# [kilter]   74000 inserted so far ...
# [kilter]   75000 inserted so far ...
# [kilter]   76000 inserted so far ...
# [kilter]   77000 inserted so far ...
# [kilter]   78000 inserted so far ...
# [kilter]   79000 inserted so far ...
# [kilter]   80000 inserted so far ...
# [kilter]   81000 inserted so far ...
# [kilter]   82000 inserted so far ...
# [kilter]   83000 inserted so far ...
# [kilter]   84000 inserted so far ...
# [kilter]   85000 inserted so far ...
# [kilter]   86000 inserted so far ...
# [kilter]   87000 inserted so far ...
# [kilter]   88000 inserted so far ...
# [kilter]   89000 inserted so far ...
# [kilter]   90000 inserted so far ...
# [kilter]   91000 inserted so far ...
# [kilter]   92000 inserted so far ...
# [kilter]   93000 inserted so far ...
# [kilter]   94000 inserted so far ...
# [kilter]   95000 inserted so far ...
# [kilter]   96000 inserted so far ...
# [kilter]   97000 inserted so far ...
# [kilter]   98000 inserted so far ...
# [kilter]   99000 inserted so far ...
# [kilter]   100000 inserted so far ...
# [kilter]   101000 inserted so far ...
# [kilter]   102000 inserted so far ...
# [kilter]   103000 inserted so far ...
# [kilter]   104000 inserted so far ...
# [kilter]   105000 inserted so far ...
# [kilter]   106000 inserted so far ...
# [kilter]   107000 inserted so far ...
# [kilter]   108000 inserted so far ...
# [kilter]   109000 inserted so far ...
# [kilter]   110000 inserted so far ...
# [kilter]   111000 inserted so far ...
# [kilter]   112000 inserted so far ...
# [kilter]   113000 inserted so far ...
# [kilter]   114000 inserted so far ...
# [kilter]   115000 inserted so far ...
# [kilter]   116000 inserted so far ...
# [kilter]   117000 inserted so far ...
# [kilter]   118000 inserted so far ...
# [kilter]   119000 inserted so far ...
# [kilter]   120000 inserted so far ...
# [kilter]   121000 inserted so far ...
# [kilter]   122000 inserted so far ...
# [kilter]   123000 inserted so far ...
# [kilter]   124000 inserted so far ...
# [kilter]   125000 inserted so far ...
# [kilter]   126000 inserted so far ...
# [kilter]   127000 inserted so far ...
# [kilter]   128000 inserted so far ...
# [kilter]   129000 inserted so far ...
# [kilter]   130000 inserted so far ...
# [kilter]   131000 inserted so far ...
# [kilter]   132000 inserted so far ...
# [kilter]   133000 inserted so far ...
# [kilter]   134000 inserted so far ...
# [kilter]   135000 inserted so far ...
# [kilter]   136000 inserted so far ...
# [kilter]   137000 inserted so far ...
# [kilter]   138000 inserted so far ...
# [kilter]   139000 inserted so far ...
# [kilter]   140000 inserted so far ...
# [kilter]   141000 inserted so far ...
# [kilter]   142000 inserted so far ...
# [kilter]   143000 inserted so far ...
# [kilter]   144000 inserted so far ...
# [kilter]   145000 inserted so far ...
# [kilter]   146000 inserted so far ...
# [kilter]   147000 inserted so far ...
# [kilter]   148000 inserted so far ...
# [kilter]   149000 inserted so far ...
# [kilter]   150000 inserted so far ...
# [kilter]   151000 inserted so far ...
# [kilter]   152000 inserted so far ...
# [kilter]   153000 inserted so far ...
# [kilter]   154000 inserted so far ...
# [kilter]   155000 inserted so far ...
# [kilter]   156000 inserted so far ...
# [kilter]   157000 inserted so far ...
# [kilter]   158000 inserted so far ...
# [kilter]   159000 inserted so far ...
# [kilter]   160000 inserted so far ...
# [kilter]   161000 inserted so far ...
# [kilter]   162000 inserted so far ...
# [kilter]   163000 inserted so far ...
# [kilter]   164000 inserted so far ...
# [kilter]   165000 inserted so far ...
# [kilter]   166000 inserted so far ...
# [kilter]   167000 inserted so far ...
# [kilter]   168000 inserted so far ...
# [kilter]   169000 inserted so far ...
# [kilter]   170000 inserted so far ...
# [kilter]   171000 inserted so far ...
# [kilter]   172000 inserted so far ...
# [kilter]   173000 inserted so far ...
# [kilter]   174000 inserted so far ...
# [kilter]   175000 inserted so far ...
# [kilter]   176000 inserted so far ...
# [kilter]   177000 inserted so far ...
# [kilter]   178000 inserted so far ...
# [kilter]   179000 inserted so far ...
# [kilter]   180000 inserted so far ...
# [kilter]   181000 inserted so far ...
# [kilter]   182000 inserted so far ...
# [kilter]   183000 inserted so far ...
# [kilter]   184000 inserted so far ...
# [kilter]   185000 inserted so far ...
# [kilter]   186000 inserted so far ...
# [kilter]   187000 inserted so far ...
# [kilter]   188000 inserted so far ...
# [kilter]   189000 inserted so far ...
# [kilter]   190000 inserted so far ...
# [kilter]   191000 inserted so far ...
# [kilter]   192000 inserted so far ...
# [kilter]   193000 inserted so far ...
# [kilter]   194000 inserted so far ...
# [kilter]   195000 inserted so far ...
# [kilter]   196000 inserted so far ...
# [kilter]   197000 inserted so far ...
# [kilter]   198000 inserted so far ...
# [kilter]   199000 inserted so far ...
# [kilter]   200000 inserted so far ...
# [kilter]   201000 inserted so far ...
# [kilter]   202000 inserted so far ...
# [kilter]   203000 inserted so far ...
# [kilter]   204000 inserted so far ...
# [kilter]   205000 inserted so far ...
# [kilter]   206000 inserted so far ...
# [kilter]   207000 inserted so far ...
# [kilter]   208000 inserted so far ...
# [kilter]   209000 inserted so far ...
# [kilter]   210000 inserted so far ...
# [kilter]   211000 inserted so far ...
# [kilter]   212000 inserted so far ...
# [kilter]   213000 inserted so far ...
# [kilter]   214000 inserted so far ...
# [kilter]   215000 inserted so far ...
# [kilter]   216000 inserted so far ...
# [kilter]   217000 inserted so far ...
# [kilter]   218000 inserted so far ...
# [kilter]   219000 inserted so far ...
# [kilter]   220000 inserted so far ...
# [kilter]   221000 inserted so far ...
# [kilter]   222000 inserted so far ...
# [kilter]   223000 inserted so far ...
# [kilter]   224000 inserted so far ...
# [kilter]   225000 inserted so far ...
# [kilter]   226000 inserted so far ...
# [kilter]   227000 inserted so far ...
# [kilter]   228000 inserted so far ...
# [kilter]   229000 inserted so far ...
# [kilter]   230000 inserted so far ...
# [kilter]   231000 inserted so far ...
# [kilter]   232000 inserted so far ...
# [kilter]   233000 inserted so far ...
# [kilter]   234000 inserted so far ...
# [kilter]   235000 inserted so far ...
# [kilter]   236000 inserted so far ...
# [kilter]   237000 inserted so far ...
# [kilter]   238000 inserted so far ...
# [kilter]   239000 inserted so far ...
# [kilter]   240000 inserted so far ...
# [kilter]   241000 inserted so far ...
# [kilter]   242000 inserted so far ...
# [kilter]   243000 inserted so far ...
# [kilter]   244000 inserted so far ...
# [kilter]   245000 inserted so far ...
# [kilter]   246000 inserted so far ...
# [kilter]   247000 inserted so far ...
# [kilter]   248000 inserted so far ...
# [kilter]   249000 inserted so far ...
# [kilter]   250000 inserted so far ...
# [kilter]   251000 inserted so far ...
# [kilter]   252000 inserted so far ...
# [kilter]   253000 inserted so far ...
# [kilter]   254000 inserted so far ...
# [kilter]   255000 inserted so far ...
# [kilter]   256000 inserted so far ...
# [kilter]   257000 inserted so far ...
# [kilter]   258000 inserted so far ...
# [kilter]   259000 inserted so far ...
# [kilter]   260000 inserted so far ...
# [kilter]   261000 inserted so far ...
# [kilter]   262000 inserted so far ...
# [kilter]   263000 inserted so far ...
# [kilter]   264000 inserted so far ...
# [kilter]   265000 inserted so far ...
# [kilter]   266000 inserted so far ...
# [kilter]   267000 inserted so far ...
# [kilter]   268000 inserted so far ...
# [kilter]   269000 inserted so far ...
# [kilter]   270000 inserted so far ...
# [kilter]   271000 inserted so far ...
# [kilter]   272000 inserted so far ...
# [kilter]   273000 inserted so far ...
# [kilter]   274000 inserted so far ...
# [kilter]   275000 inserted so far ...
# [kilter]   276000 inserted so far ...
# [kilter]   277000 inserted so far ...
# [kilter]   278000 inserted so far ...
# [kilter]   279000 inserted so far ...
# [kilter]   280000 inserted so far ...
# [kilter]   281000 inserted so far ...
# [kilter]   282000 inserted so far ...
# [kilter]   283000 inserted so far ...
# [kilter]   284000 inserted so far ...
# [kilter]   285000 inserted so far ...
# [kilter]   286000 inserted so far ...
# [kilter]   287000 inserted so far ...
# [kilter] Done — 287641 inserted, 0 skipped.
# [kilter] Role map: {12: 0, 13: 2, 14: 1, 15: 3, 20: 0, 21: 2, 22: 1, 23: 3, 24: 0, 25: 2, 26: 1, 27: 3, 28: 0, 29: 2, 30: 1, 31: 3, 32: 0, 33: 2, 34: 1, 35: 3, 42: 0, 43: 2, 44: 1, 45: 3}
# [kilter, layout id 8] 43937 candidate (climb, angle) pairs.
# [kilter]   288641 inserted so far ...
# [kilter]   289641 inserted so far ...
# [kilter]   290641 inserted so far ...
# [kilter]   291641 inserted so far ...
# [kilter]   292641 inserted so far ...
# [kilter]   293641 inserted so far ...
# [kilter]   294641 inserted so far ...
# [kilter]   295641 inserted so far ...
# [kilter]   296641 inserted so far ...
# [kilter]   297641 inserted so far ...
# [kilter]   298641 inserted so far ...
# [kilter]   299641 inserted so far ...
# [kilter]   300641 inserted so far ...
# [kilter]   301641 inserted so far ...
# [kilter]   302641 inserted so far ...
# [kilter]   303641 inserted so far ...
# [kilter]   304641 inserted so far ...
# [kilter]   305641 inserted so far ...
# [kilter]   306641 inserted so far ...
# [kilter]   307641 inserted so far ...
# [kilter]   308641 inserted so far ...
# [kilter]   309641 inserted so far ...
# [kilter]   310641 inserted so far ...
# [kilter]   311641 inserted so far ...
# [kilter]   312641 inserted so far ...
# [kilter]   313641 inserted so far ...
# [kilter]   314641 inserted so far ...
# [kilter]   315641 inserted so far ...
# [kilter]   316641 inserted so far ...
# [kilter]   317641 inserted so far ...
# [kilter]   318641 inserted so far ...
# [kilter]   319641 inserted so far ...
# [kilter]   320641 inserted so far ...
# [kilter]   321641 inserted so far ...
# [kilter]   322641 inserted so far ...
# [kilter]   323641 inserted so far ...
# [kilter]   324641 inserted so far ...
# [kilter]   325641 inserted so far ...
# [kilter]   326641 inserted so far ...
# [kilter]   327641 inserted so far ...
# [kilter]   328641 inserted so far ...
# [kilter]   329641 inserted so far ...
# [kilter]   330641 inserted so far ...
# [kilter] Done — 331578 inserted, 0 skipped.
#
# [tension] Opening data\boardlib\tension.db ...
# [tension] Role map: {1: 0, 3: 1, 4: 3, 5: 0, 7: 1, 8: 3, 2: 2, 6: 2}
# [tension, layout id 9] 74718 candidate (climb, angle) pairs.
# [tension]   1000 inserted so far ...
# [tension]   2000 inserted so far ...
# [tension]   3000 inserted so far ...
# [tension]   4000 inserted so far ...
# [tension]   5000 inserted so far ...
# [tension]   6000 inserted so far ...
# [tension]   7000 inserted so far ...
# [tension]   8000 inserted so far ...
# [tension]   9000 inserted so far ...
# [tension]   10000 inserted so far ...
# [tension]   11000 inserted so far ...
# [tension]   12000 inserted so far ...
# [tension]   13000 inserted so far ...
# [tension]   14000 inserted so far ...
# [tension]   15000 inserted so far ...
# [tension]   16000 inserted so far ...
# [tension]   17000 inserted so far ...
# [tension]   18000 inserted so far ...
# [tension]   19000 inserted so far ...
# [tension]   20000 inserted so far ...
# [tension]   21000 inserted so far ...
# [tension]   22000 inserted so far ...
# [tension]   23000 inserted so far ...
# [tension]   24000 inserted so far ...
# [tension]   25000 inserted so far ...
# [tension]   26000 inserted so far ...
# [tension]   27000 inserted so far ...
# [tension]   28000 inserted so far ...
# [tension]   29000 inserted so far ...
# [tension]   30000 inserted so far ...
# [tension]   31000 inserted so far ...
# [tension]   32000 inserted so far ...
# [tension]   33000 inserted so far ...
# [tension]   34000 inserted so far ...
# [tension]   35000 inserted so far ...
# [tension]   36000 inserted so far ...
# [tension]   37000 inserted so far ...
# [tension]   38000 inserted so far ...
# [tension]   39000 inserted so far ...
# [tension]   40000 inserted so far ...
# [tension]   41000 inserted so far ...
# [tension]   42000 inserted so far ...
# [tension]   43000 inserted so far ...
# [tension]   44000 inserted so far ...
# [tension]   45000 inserted so far ...
# [tension]   46000 inserted so far ...
# [tension]   47000 inserted so far ...
# [tension]   48000 inserted so far ...
# [tension]   49000 inserted so far ...
# [tension]   50000 inserted so far ...
# [tension]   51000 inserted so far ...
# [tension]   52000 inserted so far ...
# [tension]   53000 inserted so far ...
# [tension]   54000 inserted so far ...
# [tension]   55000 inserted so far ...
# [tension]   56000 inserted so far ...
# [tension]   57000 inserted so far ...
# [tension]   58000 inserted so far ...
# [tension]   59000 inserted so far ...
# [tension]   60000 inserted so far ...
# [tension]   61000 inserted so far ...
# [tension]   62000 inserted so far ...
# [tension]   63000 inserted so far ...
# [tension]   64000 inserted so far ...
# [tension]   65000 inserted so far ...
# [tension]   66000 inserted so far ...
# [tension]   67000 inserted so far ...
# [tension]   68000 inserted so far ...
# [tension]   69000 inserted so far ...
# [tension]   70000 inserted so far ...
# [tension]   71000 inserted so far ...
# [tension]   72000 inserted so far ...
# [tension]   73000 inserted so far ...
# [tension]   74000 inserted so far ...
# [tension] Done — 74718 inserted, 0 skipped.
# [tension] Role map: {1: 0, 3: 1, 4: 3, 5: 0, 7: 1, 8: 3, 2: 2, 6: 2}
# [tension, layout id 10] 43440 candidate (climb, angle) pairs.
# [tension]   75718 inserted so far ...
# [tension]   76718 inserted so far ...
# [tension]   77718 inserted so far ...
# [tension]   78718 inserted so far ...
# [tension]   79718 inserted so far ...
# [tension]   80718 inserted so far ...
# [tension]   81718 inserted so far ...
# [tension]   82718 inserted so far ...
# [tension]   83718 inserted so far ...
# [tension]   84718 inserted so far ...
# [tension]   85718 inserted so far ...
# [tension]   86718 inserted so far ...
# [tension]   87718 inserted so far ...
# [tension]   88718 inserted so far ...
# [tension]   89718 inserted so far ...
# [tension]   90718 inserted so far ...
# [tension]   91718 inserted so far ...
# [tension]   92718 inserted so far ...
# [tension]   93718 inserted so far ...
# [tension]   94718 inserted so far ...
# [tension]   95718 inserted so far ...
# [tension]   96718 inserted so far ...
# [tension]   97718 inserted so far ...
# [tension]   98718 inserted so far ...
# [tension]   99718 inserted so far ...
# [tension]   100718 inserted so far ...
# [tension]   101718 inserted so far ...
# [tension]   102718 inserted so far ...
# [tension]   103718 inserted so far ...
# [tension]   104718 inserted so far ...
# [tension]   105718 inserted so far ...
# [tension]   106718 inserted so far ...
# [tension]   107718 inserted so far ...
# [tension]   108718 inserted so far ...
# [tension]   109718 inserted so far ...
# [tension]   110718 inserted so far ...
# [tension]   111718 inserted so far ...
# [tension]   112718 inserted so far ...
# [tension]   113718 inserted so far ...
# [tension]   114718 inserted so far ...
# [tension]   115718 inserted so far ...
# [tension]   116718 inserted so far ...
# [tension]   117718 inserted so far ...
# [tension] Done — 118158 inserted, 0 skipped.
# [tension] Role map: {1: 0, 3: 1, 4: 3, 5: 0, 7: 1, 8: 3, 2: 2, 6: 2}
# [tension, layout id 11] 25043 candidate (climb, angle) pairs.
# [tension]   119158 inserted so far ...
# [tension]   120158 inserted so far ...
# [tension]   121158 inserted so far ...
# [tension]   122158 inserted so far ...
# [tension]   123158 inserted so far ...
# [tension]   124158 inserted so far ...
# [tension]   125158 inserted so far ...
# [tension]   126158 inserted so far ...
# [tension]   127158 inserted so far ...
# [tension]   128158 inserted so far ...
# [tension]   129158 inserted so far ...
# [tension]   130158 inserted so far ...
# [tension]   131158 inserted so far ...
# [tension]   132158 inserted so far ...
# [tension]   133158 inserted so far ...
# [tension]   134158 inserted so far ...
# [tension]   135158 inserted so far ...
# [tension]   136158 inserted so far ...
# [tension]   137158 inserted so far ...
# [tension]   138158 inserted so far ...
# [tension]   139158 inserted so far ...
# [tension]   140158 inserted so far ...
# [tension]   141158 inserted so far ...
# [tension]   142158 inserted so far ...
# [tension]   143158 inserted so far ...
# [tension] Done — 143201 inserted, 0 skipped.
#
# [grasshopper] Opening data\boardlib\grasshopper.db ...
# [grasshopper] Role map: {1: 0, 3: 1, 4: 3, 2: 2}
# [grasshopper, layout id 1] 26710 candidate (climb, angle) pairs.
# [grasshopper]   1000 inserted so far ...
# [grasshopper]   2000 inserted so far ...
# [grasshopper]   3000 inserted so far ...
# [grasshopper]   4000 inserted so far ...
# [grasshopper]   5000 inserted so far ...
# [grasshopper]   6000 inserted so far ...
# [grasshopper]   7000 inserted so far ...
# [grasshopper]   8000 inserted so far ...
# [grasshopper]   9000 inserted so far ...
# [grasshopper]   10000 inserted so far ...
# [grasshopper]   11000 inserted so far ...
# [grasshopper]   12000 inserted so far ...
# [grasshopper]   13000 inserted so far ...
# [grasshopper]   14000 inserted so far ...
# [grasshopper]   15000 inserted so far ...
# [grasshopper]   16000 inserted so far ...
# [grasshopper]   17000 inserted so far ...
# [grasshopper]   18000 inserted so far ...
# [grasshopper]   19000 inserted so far ...
# [grasshopper]   20000 inserted so far ...
# [grasshopper]   21000 inserted so far ...
# [grasshopper]   22000 inserted so far ...
# [grasshopper]   23000 inserted so far ...
# [grasshopper]   24000 inserted so far ...
# [grasshopper]   25000 inserted so far ...
# [grasshopper]   26000 inserted so far ...
# [grasshopper] Done — 26710 inserted, 0 skipped.
#
# [decoy] Opening data\boardlib\decoy.db ...
# [decoy] Role map: {1: 0, 2: 2, 3: 1, 4: 3}
# [decoy, layout id 2] 9669 candidate (climb, angle) pairs.
# [decoy]   1000 inserted so far ...
# [decoy]   2000 inserted so far ...
# [decoy]   3000 inserted so far ...
# [decoy]   4000 inserted so far ...
# [decoy]   5000 inserted so far ...
# [decoy]   6000 inserted so far ...
# [decoy]   7000 inserted so far ...
# [decoy]   8000 inserted so far ...
# [decoy]   9000 inserted so far ...
# [decoy] Done — 9669 inserted, 0 skipped.
#
# Migration complete. Total rows inserted: 511158
#         kilter:  331,578 rows
#        tension:  143,201 rows
#    grasshopper:   26,710 rows
#          decoy:    9,669 rows
# {'kilter': 331578, 'tension': 143201, 'grasshopper': 26710, 'decoy': 9669}

# %%
wall_ids = ["wall-0a877f13d8e5", "wall-443c15cd12e0", "wall-e77a688049fb", "wall-9e000814e880", "wall-0db605e544b3"]
source_ids = ["tension-10","tension-11","kilter-1","decoy-2","grasshopper-1"]
for wall_id, source_id in zip(wall_ids, source_ids):
    add_hold_useability(wall_id, source_id, min_ascents=5)
# Out:
# Loading climbs for wall 'tension-10' from data\storage.db ...
#   12420 climbs loaded.
# Computing hold useability scores ...
#   Scores computed for 498 unique holds.
# Fetching holds for API wall 'wall-0a877f13d8e5' ...
#   498 holds fetched.
#   362/498 holds updated with new useability scores.
# Uploading updated holds to API wall 'wall-0a877f13d8e5' ...
# Uploading 498 holds to wall wall-0a877f13d8e5...
# Endpoint: http://localhost:8000/api/v1/walls/wall-0a877f13d8e5/holds
# ✓ Successfully uploaded 498 holds!
# Done.
# Loading climbs for wall 'tension-11' from data\storage.db ...
#   8055 climbs loaded.
# Computing hold useability scores ...
#   Scores computed for 498 unique holds.
# Fetching holds for API wall 'wall-443c15cd12e0' ...
#   498 holds fetched.
#   139/498 holds updated with new useability scores.
# Uploading updated holds to API wall 'wall-443c15cd12e0' ...
# Uploading 498 holds to wall wall-443c15cd12e0...
# Endpoint: http://localhost:8000/api/v1/walls/wall-443c15cd12e0/holds
# ✓ Successfully uploaded 498 holds!
# Done.
# Loading climbs for wall 'kilter-1' from data\storage.db ...
#   67271 climbs loaded.
# Computing hold useability scores ...
#   Scores computed for 671 unique holds.
# Fetching holds for API wall 'wall-e77a688049fb' ...
#   641 holds fetched.
#   413/641 holds updated with new useability scores.
# Uploading updated holds to API wall 'wall-e77a688049fb' ...
# Uploading 641 holds to wall wall-e77a688049fb...
# Endpoint: http://localhost:8000/api/v1/walls/wall-e77a688049fb/holds
# ✓ Successfully uploaded 641 holds!
# Done.
# Loading climbs for wall 'decoy-2' from data\storage.db ...
#   2539 climbs loaded.
# Computing hold useability scores ...
#   Scores computed for 453 unique holds.
# Fetching holds for API wall 'wall-9e000814e880' ...
#   458 holds fetched.
#   453/458 holds updated with new useability scores.
# Uploading updated holds to API wall 'wall-9e000814e880' ...
# Uploading 458 holds to wall wall-9e000814e880...
# Endpoint: http://localhost:8000/api/v1/walls/wall-9e000814e880/holds
# ✓ Successfully uploaded 458 holds!
# Done.
# Loading climbs for wall 'grasshopper-1' from data\storage.db ...
#   6472 climbs loaded.
# Computing hold useability scores ...
#   Scores computed for 451 unique holds.
# Fetching holds for API wall 'wall-87059ecf9a99' ...
#   466 holds fetched.
#   451/466 holds updated with new useability scores.
# Uploading updated holds to API wall 'wall-87059ecf9a99' ...
# Uploading 466 holds to wall wall-87059ecf9a99...
# Endpoint: http://localhost:8000/api/v1/walls/wall-87059ecf9a99/holds
# ✓ Successfully uploaded 466 holds!
# Done.

# %%
dfg = df_sql('grasshopper', "SELECT * FROM holes", index_col='id')
dfg['x_ft'] = dfg['x']/12 + 6
dfg['y_ft'] = dfg['y']/12
dfg.sort_values('y').head()
# Out:
#     product_id   name   x  y  mirrored_hole_id  mirror_group      x_ft  \
# id
# 1            1  -64,4 -64  4               289             0  0.666667
# 37           1  -48,4 -48  4               253             0  2.000000
# 36           1  -56,4 -56  4               288             0  1.333333
# 73           1  -32,4 -32  4               217             0  3.333333
# 72           1  -40,4 -40  4               252             0  2.666667
#
#         y_ft
# id
# 1   0.333333
# 37  0.333333
# 36  0.333333
# 73  0.333333
# 72  0.333333

# %%
dfp = df_sql("grasshopper", "SELECT * FROM placements", "id")
dfp = pd.merge(dfp, dfg, left_on="hole_id", right_index=True, how="inner")[['default_placement_role_id', "x_ft", "y_ft"]]
dfp['is_foot'] = (dfp['default_placement_role_id']==4)
dfp
# Out:
#      default_placement_role_id      x_ft       y_ft  is_foot
# id
# 1                            2  2.666667  10.333333    False
# 2                            2  2.666667   9.666667    False
# 3                            2  2.666667   9.000000    False
# 4                            2  2.666667   8.333333    False
# 5                            2  2.666667   7.666667    False
# ..                         ...       ...        ...      ...
# 462                          2  6.333333   8.000000    False
# 463                          2  6.333333   8.666667    False
# 464                          2  6.333333   9.333333    False
# 465                          2  6.333333  10.666667    False
# 466                          2  6.333333  11.333333    False
#
# [466 rows x 4 columns]

# %%
holds = convert_dataframe_to_holds(dfp)
upload_holds('wall-0db605e544b3',holds)
# delete_wall('wall-e8ced52d826f')
# Out:
# Uploading 466 holds to wall wall-0db605e544b3...
# Endpoint: http://localhost:8000/api/v1/walls/wall-0db605e544b3/holds
# ✓ Successfully uploaded 466 holds!
# {'id': 'wall-0db605e544b3'}

# %%
query="""
        SELECT 
            c.uuid,
            c.name,
            cs.angle,
            c.frames,
            cs.difficulty_average,
            cs.quality_average,
            cs.fa_username,
            c.created_at
        FROM climbs c
        JOIN climb_stats cs ON c.uuid = cs.climb_uuid
        WHERE cs.difficulty_average IS NOT NULL
            AND cs.quality_average IS NOT NULL
        ORDER BY cs.ascensionist_count DESC;
    """
df_climbs = df_sql("grasshopper",query)
df_climbs['ascensionist_count'] = 1

upload_climbs_batch(
    'wall-87059ecf9a99',
    df_climbs,
)
# Out:
# Progress: 500/27290 | Success: 0 | Errors: 500
# Progress: 1000/27290 | Success: 0 | Errors: 1000
# Progress: 1500/27290 | Success: 0 | Errors: 1500
# Progress: 2000/27290 | Success: 0 | Errors: 2000
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\EvanM\anaconda3\envs\DataScience\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 20
#      17 df_climbs = df_sql("grasshopper",query)
#      18 df_climbs['ascensionist_count'] = 1
# ---> 20 upload_climbs_batch(
#      21     'wall-87059ecf9a99',
#      22     df_climbs,
#      23 )
#
# File c:\Users\EvanM\Documents\Projects\GitHub\ml-homewall-climb-generator\model-training\boardlib_preprocessing.py:249, in upload_climbs_batch(wall_id, df, role_map, base_url, batch_size, verbose, try_one)
#     247 if climbs:
#     248     try:
# --> 249         response = requests.post(endpoint, json={'climbs': climbs})
#     251         if response.status_code == 201:
#     252             batch_results = response.json()['results']
#
# File c:\Users\EvanM\anaconda3\envs\DataScience\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\EvanM\anaconda3\envs\DataScience\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\EvanM\anaconda3\envs\DataScience\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\EvanM\anaconda3\envs\DataScience\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\EvanM\anaconda3\envs\DataScience\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\Users\EvanM\anaconda3\envs\DataScience\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\EvanM\anaconda3\envs\DataScience\Lib\site-packages\urllib3\connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#     507 except BrokenPipeError:
#
# File c:\Users\EvanM\anaconda3\envs\DataScience\Lib\site-packages\urllib3\connection.py:494, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     492 for header, value in headers.items():
#     493     self.putheader(header, value)
# --> 494 self.endheaders()
#     496 # If we're given a body we start sending that in chunks.
#     497 if chunks is not None:
#
# File c:\Users\EvanM\anaconda3\envs\DataScience\Lib\http\client.py:1333, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1331 else:
#    1332     raise CannotSendHeader()
# -> 1333 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\EvanM\anaconda3\envs\DataScience\Lib\http\client.py:1093, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1091 msg = b"\r\n".join(self._buffer)
#    1092 del self._buffer[:]
# -> 1093 self.send(msg)
#    1095 if message_body is not None:
#    1096
#    1097     # create a consistent interface to message_body
#    1098     if hasattr(message_body, 'read'):
#    1099         # Let file-like take precedence over byte-like.  This
#    1100         # is needed to allow the current position of mmap'ed
#    1101         # files to be taken into account.
#
# File c:\Users\EvanM\anaconda3\envs\DataScience\Lib\http\client.py:1037, in HTTPConnection.send(self, data)
#    1035 if self.sock is None:
#    1036     if self.auto_open:
# -> 1037         self.connect()
#    1038     else:
#    1039         raise NotConnected()
#
# File c:\Users\EvanM\anaconda3\envs\DataScience\Lib\site-packages\urllib3\connection.py:325, in HTTPConnection.connect(self)
#     324 def connect(self) -> None:
# --> 325     self.sock = self._new_conn()
#     326     if self._tunnel_host:
#     327         # If we're tunneling it means we're connected to our proxy.
#     328         self._has_connected_to_proxy = True
#
# File c:\Users\EvanM\anaconda3\envs\DataScience\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File c:\Users\EvanM\anaconda3\envs\DataScience\Lib\site-packages\urllib3\util\connection.py:81, in create_connection(address, timeout, source_address, socket_options)
#      79         err = _
#      80         if sock is not None:
# ---> 81             sock.close()
#      83 if err is not None:
#      84     try:
#
# File c:\Users\EvanM\anaconda3\envs\DataScience\Lib\socket.py:501, in socket.close(self)
#     497 def _real_close(self, _ss=_socket.socket):
#     498     # This function should not reference any globals. See issue #808164.
#     499     _ss.close(self)
# --> 501 def close(self):
#     502     # This function should not reference any globals. See issue #808164.
#     503     self._closed = True
#     504     if self._io_refs <= 0:
#
# KeyboardInterrupt:

# %%
df_climbs = df_sql("grasshopper","SELECT * FROM climbs")
from sklearn.preprocessing import MinMaxScaler
grades_dict = {}
for i, row in df_climbs.iterrows():
    try:
        holdset = parse_frames_to_holdset(row['frames'])
        for h in [h for l in holdset.values() for h in l]:
            if h not in grades_dict:
                grades_dict[h] = []
            grades_dict[h].append(row['difficulty_average'])
    except:
        continue
scaler = MinMaxScaler(feature_range=(1,100))
df_hold_diff = pd.DataFrame(np.array([[k,1/np.mean(v)] for k, v in grades_dict.items()]), columns=['hold_index','difficulty_level']).set_index('hold_index')
df_hold_diff['difficulty_level'] = np.round(scaler.fit_transform(df_hold_diff[['difficulty_level']])/100,2)
df_hold_diff.sort_values('difficulty_level')
# Out:
# c:\Users\EvanM\anaconda3\envs\DataScience\Lib\site-packages\numpy\_core\fromnumeric.py:3824: RuntimeWarning: Mean of empty slice
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\EvanM\anaconda3\envs\DataScience\Lib\site-packages\numpy\_core\_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\EvanM\anaconda3\envs\DataScience\Lib\site-packages\sklearn\utils\_array_api.py:794: RuntimeWarning: All-NaN slice encountered
#   return xp.asarray(numpy.nanmin(X, axis=axis))
# c:\Users\EvanM\anaconda3\envs\DataScience\Lib\site-packages\sklearn\utils\_array_api.py:814: RuntimeWarning: All-NaN slice encountered
#   return xp.asarray(numpy.nanmax(X, axis=axis))
#             difficulty_level
# hold_index
# 152.0                    NaN
# 47.0                     NaN
# 12.0                     NaN
# 93.0                     NaN
# 85.0                     NaN
# ...                      ...
# 315.0                    NaN
# 416.0                    NaN
# 178.0                    NaN
# 100.0                    NaN
# 53.0                     NaN
#
# [307 rows x 1 columns]

# %%
query='SELECT * FROM holes'
df_holes = df_sql("decoy", query, index_col='id').astype({'product_id':int, 'name':str,'x':int,'y':int,'mirrored_hole_id':int,'mirror_group':int})
df_holes.head()

# %%
sns.scatterplot(df_holes, x='x',y='y')

# %% [markdown]
# ### Product 4 is the TB1, Product 5 is the TB2. We need to convert both of these hold-sets to real, physical holds. First step would be aligning them with their real, physical location on the board. Second step would be finding some way to manually add pull_dir+useability features.
#
# I learned from the TB2 installation guide that these hole location measurements are in inches. Additionally, the TB2 DOESN'T HAVE A KICKBOARD! That's crazy, and a bit of a Mandela effect for me. I could swear it had one. But nope.
#
# **The guide also comes with crystal clear hold orientations, and difficulty levels. This is exactly the data I'm looking for! Fuck yeah, Tension!**

# %%
query = "SELECT * FROM placements WHERE layout_id = 2"
df_placements = df_sql("decoy",query,index_col=None).astype({'id':int,'layout_id':int,'hole_id':int,'set_id':int,'default_placement_role_id':int})
df_placements = pd.merge(
    df_placements,
    df_holes,
    left_on='hole_id',
    right_on=df_holes.index,
    how='inner'
)
min_x = df_placements['x'].min()
df_placements.loc[df_placements['id'].isin([950, 935]), 'y'] += 8
df_placements['x_ft'] = (df_placements['x']+8.5-min_x)/12
df_placements['y_ft'] = (df_placements['y']+8)/12
df_placements['is_foot'] = (df_placements['default_placement_role_id']%4==0).astype(int)
df_placements = df_placements[['id','hole_id','x_ft','y_ft','is_foot']].sort_values('id')
print(
    df_placements['x_ft'].max(),
    df_placements['y_ft'].max()
)
df_placements.head()

# %%
decoy_holds = convert_dataframe_to_holds(df_placements)
upload_holds('wall-9e000814e880',decoy_holds)

# %%
flush_backup_holds("wall-e77a688049fb")

# %%
from sklearn.preprocessing import MinMaxScaler
grades_dict = {}
for i, row in df_climbs.iterrows():
    try:
        holdset = parse_frames_to_holdset(row['frames'])
        for h in [h for l in holdset.values() for h in l]:
            if h not in grades_dict:
                grades_dict[h] = []
            grades_dict[h].append(row['difficulty_average'])
    except:
        continue
scaler = MinMaxScaler(feature_range=(1,100))
df_hold_diff = pd.DataFrame(np.array([[k,1/np.mean(v)] for k, v in grades_dict.items()]), columns=['hold_index','difficulty_level']).set_index('hold_index')
df_hold_diff['difficulty_level'] = np.round(scaler.fit_transform(df_hold_diff[['difficulty_level']])/100,2)
df_hold_diff.sort_values('difficulty_level')
